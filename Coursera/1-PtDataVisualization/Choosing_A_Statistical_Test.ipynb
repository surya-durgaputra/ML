# %% [markdown]
# In the steps to choosing what statistical tests to run, we study the following factors:
#
# # Step 1:

# %% [markdown]
# #### Type of variable
# We first identify what kind of variable we have for which we wish to do a statistical test. The type of variable determines the test we will run.
#
# 1) Numerical
#     - Continuous
#     - Discrete
# 2) Categorical
#
# ### IMPORTANT:
# - If the data is Numerical Continuous, it is usually summarized as means.
# - If the data is Numerical Discrete, it often does not follow normal distribution and is usually summarized as medians.
# - Categorical data is usually summarized as proportions.

# %% [markdown]
# # Step 2:

# %% [markdown]
# #### Type of analysis:
# 1) **Comparison:**
#     Comparison can be
#         - Comparison of mean
#         - Comparison of median
#         - Comparison of proportion
#     In Comparison, we have 2 or more variables and we decide upon the type of comparison from among the 3(mean, median, proportion)
#
# 2) **Relation between two variables (correlation)**
#
#     Here we have two variables, say blood-pressure and body-weight and a group of people from whom we get both the variables. And we are trying to measure if and how much correlation is there between blood-pressure and body-weight.
#
# 3) **Predicting one varriable (Regression) from another.**
#
#     For example, if a 50kg person comes to a clinic, and we need to guess the person's blood-pressure. Here we are trying to predict one variable from another.
#
#     **Classification** : Whether a parameter belongs to a certain class. Classification belongs to this category.

# %% [markdown]
# # Step 3

# %% [markdown]
# **Number of groups and datasets.**

# %% [markdown]
# It can be:
#
#     1) One group - two or more datasets
#         Example: We have a group of patients. We take the blood pressure before and after administering a drug. Here we have two datasets (of blood-pressure of same patients in the group)
#         Another Example: a group of hypertensive patients. We first take their Blood pressure. Then they are given anti-hypertensive drug. Then we take 4 more blood-pressure readings, each at intervals of 3 hours. So, we have 5 datasets from the same group.
#
#     2) Two groups - two or more datasets.
#         Example: We are evaluating a new anti-hypertiensive drug. We have a group of hypertensive patients and we measure their blood-pressure before and after administering the drug. We have a totally different group of hypertensive patients and we give them a standard hypertensive medication and take their blood-pressures before and after administering the standard drug. Here we will have 2 datasets per group.
#
#     3) More groups -
#      Example- We have three totally separate groups of hypertiensive patients and we administer the new drug to one group, another standard drug to the second group and yet another standard drug to the third group. We take the blood pressure of everyone in each group before and after admistration of drug.

# %% [markdown]
# # Step 4

# %% [markdown]
# #### Study Design
# We need to decide if its an Unpaired or paired design.
#
# 1) Unpaired/Independent Design:
#
#     There are two or more groups that are not related or independent of eachother. These two or more groups are formed of totally unrelated subjects.
#
#     For example: We give an anti-depressant drug to a group. A different anti-depressant drug to a different group. And so on.
#
# 2) Paired/Matched Design:
#
#  The readings from the groups involved are matched to eachother.
#
#  For example we have one group. We take a set of blood-pressure measurements before giving a drug. We take a second set of blood-pressure measurements after giving the drug. Here the data from one group is paired with the data from the other. These data are always paired (the blood-pressure of a patient before and after the drug).

# %% [markdown]
# # Step 5

# %% [markdown]
# #### Distribution of data
# Here we try to see which distribution fits the data.

# %% [markdown]
# 1) Normal Distribution
#
# 2) Non - Normal distribution
#
# 3) Dichotomous (or Binomial) distribution

# %% [markdown]
# _______________________________________________________________________________________________________

# %% [markdown]
# # An Example:
#
# Now that we have outlined the steps involved in figuring out what steps to take to identify which statistical tests to run, we go through an example scenario.
#
# **Aim:** To study the effect of antidiabetic effect of a new drug
#
# 1) **Type of analysis**: Comparison of mean between two groups.
#
# More Explanation: from 3 below, we have two groups. Since blood glucose is a continuous variable, we summarize it using mean. So we will be doing a comparison of mean blood glucose levels between the two groups.
#
# 2) **List all the parameters to be analyzed.** For example, lets say: Reduction in blood glucose. (Here we have only one parameter, but there can be more than one)
#
# 3) **Number of groups and datasets and what are they**:
#     - 2 groups and 2 data sets
#         - one goup receives medformin (a standard diabetic drug)
#         - the other group receives the new drug.
#         - we capture the data before and after administering the drug.
#
# 4) **Study Design in this group**:
#     Groups are unrelated. So this is an Unpaired design.
#
# 5) **Distribution**: Blood glucose is a body parameter and it follows a normal distribution.

# %%
from IPython.display import Image
Image("images/Chart.png")

# %% [markdown]
# so, for our test, we see that we will do Unpaired t test.
